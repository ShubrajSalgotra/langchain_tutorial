# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
load_dotenv()
# Out:
# True

# %%
model = init_chat_model(
    "openai:gpt-4o-mini",
    temperature = 0.7
)

# %%
prompt = ChatPromptTemplate.from_template("Explain {topic} in simple words")

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "Your are Python instructor"),  
    ("human", "Explain {topic} in simple words to {age} year old "), 
])

# %%
final_prompt = prompt.invoke({
    "topic": "Python",
    "age": 10
})

# %%
# response = model.invoke("What is Python?")
response = model.invoke(final_prompt)

# %%
response.content
# Out:
# 'Sure! \n\nPython is like a special language that people use to talk to computers. Just like you might use English to tell a story or ask a question, programmers use Python to tell computers what to do. \n\nWith Python, you can create games, build websites, or even make robots do cool things! It’s a favorite language for beginners because it’s easy to read and understand, kind of like reading a book. \n\nImagine you have a magic box (the computer) and you want to tell it to draw a picture or solve a math problem. You use Python to write down the steps it needs to follow, and then the magic box makes it happen! \n\nSo, in short, Python helps you give instructions to computers in a way that’s simple and fun!'

# %%
# chain = prompt | model | parser

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain.chat_models import init_chat_model
from langchain_core.output_parsers import StrOutputParser

# %%
model = init_chat_model("openai:gpt-4o-mini")

# %%
prompt = ChatPromptTemplate.from_template("Explain {topic} simply.")

# %%
parser = StrOutputParser()

# %%
chain = prompt | model | parser

# %%
result = chain.invoke(
    {
        'topic' : "Quantam Physics"
    }
)

# %%
result
# Out:
# "Quantum physics, or quantum mechanics, is the branch of physics that deals with the behavior of very small particles, like atoms and subatomic particles (such as electrons and photons). Here are some key concepts explained simply:\n\n1. **Wave-Particle Duality**: Particles can behave like both particles and waves. For example, light can act like a wave (which can create interference patterns) and also like a stream of particles called photons.\n\n2. **Quantization**: Energy is not continuous but comes in small, discrete packets called quanta. For instance, an electron in an atom can only exist at specific energy levels, not in between.\n\n3. **Uncertainty Principle**: Formulated by Werner Heisenberg, this principle states that you cannot precisely know both the position and momentum (speed and direction) of a particle at the same time. The more accurately you know one, the less accurately you know the other.\n\n4. **Superposition**: Particles can exist in multiple states or position
# ...
