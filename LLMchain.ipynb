# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
load_dotenv()
# Out:
# True

# %%
model = init_chat_model(
    "openai:gpt-4o-mini",
    temperature = 0.7
)

# %%
prompt = ChatPromptTemplate.from_template("Explain {topic} in simple words")

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "Your are Python instructor"),  
    ("human", "Explain {topic} in simple words to {age} year old "), 
])

# %%
final_prompt = prompt.invoke({
    "topic": "Python",
    "age": 10
})

# %%
# response = model.invoke("What is Python?")
response = model.invoke(final_prompt)

# %%
response.content
# Out:
# "Sure! \n\nPython is like a magical language that we use to talk to computers. Just like you use English to tell your friends what you want, we use Python to tell computers what to do. \n\nWith Python, you can create games, build websites, and even make robots! It's pretty easy to learn because it uses simple words and sentences, kind of like how you write in school. \n\nImagine you have a recipe to bake cookies. Python is like a recipe for the computer, telling it step by step how to do things. So, if you want to make a game where a cat jumps over obstacles, you can write that in Python, and the computer will follow your instructions to make it happen!\n\nIn short, Python is a fun way to talk to computers and create cool things!"
